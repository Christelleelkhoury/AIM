# %% [markdown]
# # Notebook for practical exercises | Week #2 Lesson #1
#
# ## Introduction
#
# This notebook contains practical hands-on exercises for the lesson about *Data Collection and Cleaning Techniques*.
#
# After this session, you will know how to prepare a medical imaging dataset for training:
# * Import and read medical images using Python ;
# * Extract relevant radiomic features ;
# * Split the dataset into train/valid/test ;
# * Clean data: handle missing values, remove duplicates, normalize features.

# %% [markdown]
# ## Dataset
#
# In the following, we will use the [The Brain Resection Multimodal Imaging Database](https://www.cancerimagingarchive.net/collection/remind/) [1]. The Brain Resection Multimodal Imaging Database (ReMIND) contains pre- and intra-operative data collected on 114 consecutive patients who were surgically treated with image-guided tumor resection between 2018 and 2022.
#
# [1] Juvekar, P., Dorent, R., Kögl, F., Torio, E., Barr, C., Rigolo, L., Galvin, C., Jowkar, N., Kazi, A., Haouchine, N., Cheema, H., Navab, N., Pieper, S., Wells, W. M., Bi, W. L., Golby, A., Frisken, S., & Kapur, T. (2023). The Brain Resection Multimodal Imaging Database (ReMIND) (Version 1) [dataset]. The Cancer Imaging Archive. [https://doi.org/10.7937/3RAG-D070](https://doi.org/10.7937/3RAG-D070)

# %%
import pydicom
import nrrd

import SimpleITK as sitk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import model_selection
from glob import glob
from radiomics import featureextractor

import sys 
sys.path.append('../../')
from utils.sitk_utils import load_dicom_series_to_3d_image, convert_np_to_sitk, resample_mask_to_image

# %%
DATA_PATH = '../../../manifest-1695134609823'

# %% [markdown]
# ### Metadata

# %%
# Load and observe available data
clinical_df = pd.read_csv(f'{DATA_PATH}/ReMIND_metadata.csv')
clinical_df.head() # Print the 5 fist rows of the dataframe
# Out:
#    Case Number  Age     Sex   Race     Ethnicity Laterality  \
# 0            1   41    Male  White  Not Hispanic      Right
# 1            2   22  Female  White  Not Hispanic      Right
# 2            3   30    Male  Asian  Not Hispanic       Left
# 3            4   23    Male  White      Hispanic       Left
# 4            5   27    Male  White  Not Hispanic      Right
#
#   Previous Craniotomy     WHO Grade  \
# 0                  No             3
# 1                  No             2
# 2                  No             2
# 3                  No             1
# 4                  No  Not assigned
#
#                                       Histopathology
# 0                                        Astrocytoma
# 1                                        Astrocytoma
# 2                                  Oligodendroglioma
# 3             Dysembryoplastic neuroepithelial tumor
# 4  Non-tumor epileptogenic brain parenchyma and g...

# %%
# Observe variables
clinical_df.columns
# Out:
# Index(['Case Number', 'Age', 'Sex', 'Race', 'Ethnicity', 'Laterality',
#        'Previous Craniotomy', 'WHO Grade', 'Histopathology'],
#       dtype='object')

# %% [markdown]
# We aim to train a model using pre-operative brain MRI scans to classify tumor grade (column **WHO Grade**). To do so, we need to make sure that the features we will be using are correct.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Q1.</b> Observe the unique values in column <b>WHO Grade</b>, and identify issues that should be corrected.
# </div>

# %%
clinical_df['WHO Grade'].unique() # To observe the different labels in this column
# Out:
# array(['3', '2', '1', 'Not assigned', '4'], dtype=object)

# %% [markdown]
# The column contains missing values. We need to drop the corresponding samples.

# %%
clinical_df = clinical_df.loc[clinical_df['WHO Grade']!='...'] # Replace ... with the value corresponding to missing labels. 
clinical_df = clinical_df.loc[clinical_df['WHO Grade']!='Not assigned'] # Correction

# %%
clinical_df['WHO Grade'].unique() # No more missing values
# Out:
# array(['3', '2', '1', '4'], dtype=object)

# %% [markdown]
# ### Images

# %% [markdown]
# Now that we have a dataframe containing only samples that can be used for the classification, we need to find the corresponding image.
# The column **Case Number** (sometimes also called **ID** in standard dataframes) provides a unique identifier for each patient. Now, our goal will be to link the images to their corresponding rows in the dataframes.

# %%
sorted(glob(f'{DATA_PATH}/ReMIND/*'))[0:5] # This command looks for folders within the dataset and displays the 5 first
# Out:
# ['../../../manifest-1695134609823/ReMIND/LICENSE',
#  '../../../manifest-1695134609823/ReMIND/ReMIND-001',
#  '../../../manifest-1695134609823/ReMIND/ReMIND-002',
#  '../../../manifest-1695134609823/ReMIND/ReMIND-003',
#  '../../../manifest-1695134609823/ReMIND/ReMIND-004']

# %% [markdown]
# In the dataset, each folder is named **ReMIND-XXX**, wich **XXX** representing the corresponding patient ID. Now, we will explore the content of a patient folder.
#
# Folders are organized in the following way:
# ```bash
# ReMIND-001/
# ├── XX-XX-XXXX-NA-Intraop-XXXXX/                      # Intra-operative scans
# └── XX-XX-XXXX-NA-Preop-XXXXX/                        # Pre-operative scans
#     ├── XXXXXXXX-3DAXT1postcontrast-XXXX/             # T1 post-contrast sequence
#     └── XXXXXXXX-3DSAGT2FLAIR-XXXX/                   # T2 FLAIR sequence
#         ├── 1-001.dcm                                 # Images in DICOM format
#         ├── 1-002.dcm
#         ├── 1-003.dcm
#         └── ...
# ```

# %% [markdown]
# In the following, we will focus on pre-operative T1 gadolinium enhanced MRI, which can be used to identify and locate tumors.
# The images are located in a folder containing the label **3DAXT1postcontrast** for each patient.
#
# Now, let's verify if we have an image for each patient in our dataframe.

# %%
for patient in clinical_df['Case Number']:
    idx = str(patient).zfill(3)

    if len(glob(f'{DATA_PATH}/ReMIND/ReMIND-{idx}/*Preop*/*3D*T1*')) == 0:
        print('No T1w image for patient n.', idx)
# Out:
# No T1w image for patient n. 065
# No T1w image for patient n. 096

# %% [markdown]
# Two patients do not have pre-operative T1w images. We will thus have to remove them from the list when computing the features.
#
# Now, we will explore the structure of a DICOM file, and how we can read it with Python.

# %%
t1w_file = glob(f'{DATA_PATH}/ReMIND/ReMIND-001/*Preop*/*3D*T1*/1-080.dcm')[0]
image = pydicom.dcmread(t1w_file)

# %% [markdown]
# The dcmread function from the pydicom library allows to read DICOM files and store their content in a Python object. Let's explore its different attributes.

# %%
image
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.241234373646560912433565108058941598584
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0013) Implementation Version Name         SH: '0.5'
# (0002, 0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'MPR']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.241234373646560912433565108058941598584
# (0008, 0020) Study Date                          DA: '19821225'
# (0008, 0021) Series Date                         DA: '20070308'
# (0008, 0023) Content Date                        DA: '20070308'
# (0008, 0030) Study Time                          TM: '171026'
# (0008, 0031) Series Time                         TM: '171026'
# (0008, 0033) Content Time                        TM: '171026'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'Unknown manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Preop'
# (0008, 103e) Series Description                  LO: '3D_AX_T1_postcontrast'
# (0008, 1090) Manufacturer's Model Name           LO: 'Unknown model'
# (0010, 0010) Patient's Name                      PN: 'ReMIND-001'
# (0010, 0020) Patient ID                          LO: 'ReMIND-001'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: ['PyDeface-NiftyReg', 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064']
# (0012, 0064)  De-identification Method Code Sequence  8 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113104'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Structured Content Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'ReMIND'
# (0013, 1013) Private tag data                    UN: b'36715678'
# (0018, 0020) Scanning Sequence                   CS: 'RM'
# (0018, 0021) Sequence Variant                    CS: 'NONE'
# (0018, 0022) Scan Options                        CS: ''
# (0018, 0023) MR Acquisition Type                 CS: ''
# (0018, 0050) Slice Thickness                     DS: '1.0'
# (0018, 0080) Repetition Time                     DS: None
# (0018, 0081) Echo Time                           DS: None
# (0018, 0088) Spacing Between Slices              DS: '1.0'
# (0018, 0091) Echo Train Length                   IS: None
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.260497661906193334514226770342365856579
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.203358765267234045641494108066491494802
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0013) Instance Number                     IS: '80'
# (0020, 0032) Image Position (Patient)            DS: [141.196, -124.004, -10.1512]
# (0020, 0037) Image Orientation (Patient)         DS: [-.752195, -.652188, .0940932, -.648901, .757975, .0663376]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.15406225903043740751527022288377871160
# (0020, 0060) Laterality                          CS: ''
# (0020, 1040) Position Reference Indicator        LO: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 216
# (0028, 0030) Pixel Spacing                       DS: [.976562578063547, .976562594935198]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '683.0'
# (0028, 1051) Window Width                        DS: '1366.0'
# (0028, 1054) Rescale Type                        LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 110592 elements

# %% [markdown]
# We can access DICOM headers' information using their name. For instance, to obtain the image type, run `image.ImageType`

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Q2.</b> Explore other informations contained in DICOM headers using similar commands.
# </div>

# %%
...

# %% [markdown]
# Now, we will try to better understand how the images are stored. We can see in the header that we have images of dimension 256 x 216 (see attributes `Rows` and `Columns`). In Python, this means that the image corresponds to an **array** with 256 rows and 216 columns, with each **cell** corresponding to the pixel intensity value. This array is stored in the attribute `pixel_array` of the image, and the `matplotlib` library allows to plot images stored as pixel intensity arrays.

# %%
plt.imshow(image.pixel_array, cmap=plt.cm.bone)
plt.show()

# %% [markdown]
# Note that the images are 3D volumes, but DICOM files only contain slices. To load the full volume in a single array, we would have to loop over the slices and stack them to create a full volume. In practice, we will prefer to use `NIfTI` files (see practical session of Lesson 3 for more details).

# %% [markdown]
# ### Derivatives
#
# The dataset we are using contains segmentation masks stored in **NRRD** format. These segmentation masked have been drawn manually by two neurosurgeons, and represent the boundaries of the tumor identified using the pre-operative MRI. In Lesson 3, we will see how you could generate these annotations by yourself.

# %% [markdown]
# Similarly to T1w images, we will verify that all patients have a pre-operative segmentation of the tumor region.

# %%
for patient in clinical_df['Case Number']:
    idx = str(patient).zfill(3)

    if len(glob(f'{DATA_PATH}/PKG - ReMIND_NRRD_Seg_Sep_2023/ReMIND-{idx}/ReMIND-{idx}-preop-SEG-tumor*.nrrd')) == 0:
        print('No pre-operative tumor segmentation for patient n.', idx)
# Out:
# No pre-operative tumor segmentation for patient n. 032

# %%
seg_file = glob(f'{DATA_PATH}/PKG - ReMIND_NRRD_Seg_Sep_2023/ReMIND-001/ReMIND-001-preop-SEG-tumor*.nrrd')[0]
mask, header = nrrd.read(seg_file)

# %% [markdown]
# The `nrrd` package allows to read such files, and store two different objects: the pixel array (`mask`) and the header (`header`).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Q3.</b> Visualize the dimensions of the mask using the <b>shape</b> function. What do you notice? How is this different from the DICOM image?
# </div>

# %%
... 
# mask.shape
# Out:
# (61, 63, 59)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Q4.</b> Use the same function as below to plot the mask image and visualize its content.
# </div>

# %%
...
# plt.imshow(mask[:,:,10])
# plt.show()

# %% [markdown]
# As you might have noticed, the function to read NRRD files outputs an array and a header. The header contains information about the image:
# * size ;
# * space directions ;
# * origin ;
# * ...

# %%
header
# Out:
# OrderedDict([('type', 'short'),
#              ('dimension', 3),
#              ('space', 'left-posterior-superior'),
#              ('sizes', array([61, 63, 59])),
#              ('space directions',
#               array([[-0.5265367 , -0.45653135,  0.06586527],
#                      [-0.4542307 ,  0.53058285,  0.0464363 ],
#                      [-0.08020945, -0.00781087, -0.69534558]])),
#              ('kinds', ['domain', 'domain', 'domain']),
#              ('endian', 'little'),
#              ('encoding', 'gzip'),
#              ('space origin',
#               array([-1.50286255e+01, -1.31630859e+02,  1.02569580e-01]))])

# %% [markdown]
# ## Feature extraction
#
# Now that we observed the different data, we will extract radiomic features and visualize these features.
# To do so, we will use `SimpleITK` to load images, and `pyradiomics` to extract features. The idea is that, given an image and a corresponding mask, the code will extract relevant metrics.
#
# A detailed description of each metrics is available at [https://pyradiomics.readthedocs.io/en/latest/features.html](https://pyradiomics.readthedocs.io/en/latest/features.html).

# %%
# First use pre-defined function to load dicom series to 3D images, load mask and resample the mask to the image space
image_sitk = load_dicom_series_to_3d_image(
    glob(f'{DATA_PATH}/ReMIND/ReMIND-001/*-Preop-*/*-3D*T1*')[0])
mask_sitk = convert_np_to_sitk(mask, header)
mask_resampled_sitk = resample_mask_to_image(mask_sitk, image_sitk)
# Out:
# [INFO] Loaded DICOM series with size: (216, 256, 192)
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line

# %% [markdown]
# The original shape of the mask was different from those of the T1w image. To compute the features, we had to resample the mask to fit the dimensions of the image.

# %% [markdown]
# We will now create the feature extractor and apply it to our image-mask pair.
# We can define specific parameters for the feature extraction. In our case, we will add a standard normalization space, aiming mitigate pixel intensity differences across MRI machines.

# %%
settings = {}

# Normalizes the image by centering it at the mean with standard deviation. 
# Normalization is based on all gray values in the image, not just those inside the segmentation.
settings['normalize'] = True

# Create the featureextractor
extractor = featureextractor.RadiomicsFeatureExtractor(**settings)

# %%
# Extract features
result = extractor.execute(image_sitk, mask_resampled_sitk)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
result
# Out:
# OrderedDict([('diagnostics_Versions_PyRadiomics', 'v3.0.1'),
#              ('diagnostics_Versions_Numpy', '1.24.4'),
#              ('diagnostics_Versions_SimpleITK', '2.4.0'),
#              ('diagnostics_Versions_PyWavelet', '1.4.1'),
#              ('diagnostics_Versions_Python', '3.8.20'),
#              ('diagnostics_Configuration_Settings',
#               {'minimumROIDimensions': 2,
#                'minimumROISize': None,
#                'normalize': True,
#                'normalizeScale': 1,
#                'removeOutliers': None,
#                'resampledPixelSpacing': None,
#                'interpolator': 'sitkBSpline',
#                'preCrop': False,
#                'padDistance': 5,
#                'distances': [1],
#                'force2D': False,
#                'force2Ddimension': 0,
#                'resegmentRange': None,
#                'label': 1,
#                'additionalInfo': True}),
#              ('diagnostics_Configuration_EnabledImageTypes', {'Original': {}}),
#              ('diagnostics_Image-original_Hash',
#               '48f04b9e46a9370ab926bb04683fe25d292b9614'),
#              ('diagnostics_Image-original_Dimensionality', '3D'),
#              ('diagnostics_Image-original_Spacing',
#               (0.976562594935198, 0.976562578063547, 1.0000021520254523)),
#              ('diagnostics_Image-original_Size', (216, 256, 192)),
#              ('diagnostics_Image-original_Mean', 145.057100272473),
#              ('diagnostics_Image-original_Minimum', 0.0),
#              ('diagnostics_Image-original_Maximum', 2293.0),
#              ('diagnostics_Mask-original_Hash',
#               '3b38ad949a281c5b0e14d1da5d3e56daab92b206'),
#              ('diagnostics_Mask-original_Spacing',
#               (0.976562594935198, 0.976562578063547, 1.0000021520254523)),
#              ('diagnostics_Mask-original_Size', (216, 256, 192)),
#              ('diagnostics_Mask-original_BoundingBox',
#               (123, 96, 91, 40, 46, 46)),
#              ('diagnostics_Mask-original_VoxelNum', 28585),
#              ('diagnostics_Mask-original_VolumeNum', 1),
#              ('diagnostics_Mask-original_CenterOfMassIndex',
#               (144.83939128913767, 120.24946650341089, 112.4040930557985)),
#              ('diagnostics_Mask-original_CenterOfMass',
#               (-45.22708186687484, -127.61589095426272, -22.234343583780955)),
#              ('original_shape_Elongation', 0.8383835085993125),
#              ('original_shape_Flatness', 0.7264595509114974),
#              ('original_shape_LeastAxisLength', 29.469635215824432),
#              ('original_shape_MajorAxisLength', 40.56610609475577),
#              ('original_shape_Maximum2DDiameterColumn', array(48.27614183)),
#              ('original_shape_Maximum2DDiameterRow', array(46.24906158)),
#              ('original_shape_Maximum2DDiameterSlice', array(45.09139579)),
#              ('original_shape_Maximum3DDiameter', array(48.35509553)),
#              ('original_shape_MeshVolume', array(27223.61070815)),
#              ('original_shape_MinorAxisLength', 34.0099543579333),
#              ('original_shape_Sphericity', array(0.7347576)),
#              ('original_shape_SurfaceArea', array(5956.21715921)),
#              ('original_shape_SurfaceVolumeRatio', array(0.21878865)),
#              ('original_shape_VoxelVolume', 27260.843829643116),
#              ('original_firstorder_10Percentile', array(0.20622978)),
#              ('original_firstorder_90Percentile', array(0.73891094)),
#              ('original_firstorder_Energy', array(8519.7290077)),
#              ('original_firstorder_Entropy', array(0.03640958)),
#              ('original_firstorder_InterquartileRange', array(0.2560173)),
#              ('original_firstorder_Kurtosis', array(35.20952445)),
#              ('original_firstorder_Maximum', array(4.8847395)),
#              ('original_firstorder_MeanAbsoluteDeviation', array(0.18905191)),
#              ('original_firstorder_Mean', array(0.45358774)),
#              ('original_firstorder_Median', array(0.39204879)),
#              ('original_firstorder_Minimum', array(-0.30167551)),
#              ('original_firstorder_Range', array(5.18641501)),
#              ('original_firstorder_RobustMeanAbsoluteDeviation',
#               array(0.10989621)),
#              ('original_firstorder_RootMeanSquared', array(0.54593859)),
#              ('original_firstorder_Skewness', array(4.15582365)),
#              ('original_firstorder_TotalEnergy', array(8125.06566205)),
#              ('original_firstorder_Uniformity', array(0.99233327)),
#              ('original_firstorder_Variance', array(0.09230711)),
#              ('original_glcm_Autocorrelation', array(3.98483057)),
#              ('original_glcm_ClusterProminence', array(0.01682143)),
#              ('original_glcm_ClusterShade', array(-0.01167401)),
#              ('original_glcm_ClusterTendency', array(0.00917886)),
#              ('original_glcm_Contrast', array(0.00659062)),
#              ('original_glcm_Correlation', array(0.1645609)),
#              ('original_glcm_DifferenceAverage', array(0.00659062)),
#              ('original_glcm_DifferenceEntropy', array(0.05720172)),
#              ('original_glcm_DifferenceVariance', array(0.00654695)),
#              ('original_glcm_Id', array(0.99670469)),
#              ('original_glcm_Idm', array(0.99670469)),
#              ('original_glcm_Idmn', array(0.99868188)),
#              ('original_glcm_Idn', array(0.99780313)),
#              ('original_glcm_Imc1', array(-0.07747952)),
#              ('original_glcm_Imc2', array(0.0740299)),
#              ('original_glcm_InverseVariance', array(0.00659062)),
#              ('original_glcm_JointAverage', array(1.99604196)),
#              ('original_glcm_JointEnergy', array(0.98556831)),
#              ('original_glcm_JointEntropy', array(0.07169535)),
#              ('original_glcm_MCC', array(0.1645609)),
#              ('original_glcm_MaximumProbability', array(0.99274665)),
#              ('original_glcm_SumAverage', array(3.99208392)),
#              ('original_glcm_SumEntropy', array(0.06510473)),
#              ('original_glcm_SumSquares', array(0.00394237)),
#              ('original_gldm_DependenceEntropy', array(2.11331264)),
#              ('original_gldm_DependenceNonUniformity', array(13694.1301032)),
#              ('original_gldm_DependenceNonUniformityNormalized',
#               array(0.479067)),
#              ('original_gldm_DependenceVariance', array(15.26857188)),
#              ('original_gldm_GrayLevelNonUniformity', array(28365.84659787)),
#              ('original_gldm_GrayLevelVariance', array(0.00383336)),
#              ('original_gldm_HighGrayLevelEmphasis', array(3.98845548)),
#              ('original_gldm_LargeDependenceEmphasis', array(641.9909393)),
#              ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#               array(2567.49819836)),
#              ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#               array(160.61412454)),
#              ('original_gldm_LowGrayLevelEmphasis', array(0.25288613)),
#              ('original_gldm_SmallDependenceEmphasis', array(0.00245848)),
#              ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#               array(0.00779929)),
#              ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#               array(0.00112327)),
#              ('original_glrlm_GrayLevelNonUniformity', array(1984.40326052)),
#              ('original_glrlm_GrayLevelNonUniformityNormalized',
#               array(0.91646487)),
#              ('original_glrlm_GrayLevelVariance', array(0.04176756)),
#              ('original_glrlm_HighGrayLevelRunEmphasis', array(3.86885329)),
#              ('original_glrlm_LongRunEmphasis', array(271.29312949)),
#              ('original_glrlm_LongRunHighGrayLevelEmphasis',
#               array(1084.94953085)),
#              ('original_glrlm_LongRunLowGrayLevelEmphasis',
#               array(67.87902915)),
#              ('original_glrlm_LowGrayLevelRunEmphasis', array(0.28278668)),
#              ('original_glrlm_RunEntropy', array(4.82475455)),
#              ('original_glrlm_RunLengthNonUniformity', array(94.61114076)),
#              ('original_glrlm_RunLengthNonUniformityNormalized',
#               array(0.04254842)),
#              ('original_glrlm_RunPercentage', array(0.07559909)),
#              ('original_glrlm_RunVariance', array(76.14285276)),
#              ('original_glrlm_ShortRunEmphasis', array(0.11244006)),
#              ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#               array(0.3357838)),
#              ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#               array(0.05660412)),
#              ('original_glszm_GrayLevelNonUniformity', array(26.07142857)),
#              ('original_glszm_GrayLevelNonUniformityNormalized',
#               array(0.93112245)),
#              ('original_glszm_GrayLevelVariance', array(0.03443878)),
#              ('original_glszm_HighGrayLevelZoneEmphasis', array(1.10714286)),
#              ('original_glszm_LargeAreaEmphasis', array(28958112.67857143)),
#              ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#               array(1.15832287e+08)),
#              ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#               array(7239569.15178571)),
#              ('original_glszm_LowGrayLevelZoneEmphasis', array(0.97321429)),
#              ('original_glszm_SizeZoneNonUniformity', array(6.57142857)),
#              ('original_glszm_SizeZoneNonUniformityNormalized',
#               array(0.23469388)),
#              ('original_glszm_SmallAreaEmphasis', array(0.4698309)),
#              ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#               array(0.4698309)),
#              ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#               array(0.4698309)),
#              ('original_glszm_ZoneEntropy', array(2.60359663)),
#              ('original_glszm_ZonePercentage', array(0.00097953)),
#              ('original_glszm_ZoneVariance', array(27915890.45280612)),
#              ('original_ngtdm_Busyness', array(22.80678374)),
#              ('original_ngtdm_Coarseness', array(0.01102529)),
#              ('original_ngtdm_Complexity', array(0.00634602)),
#              ('original_ngtdm_Contrast', array(2.44318314e-05)),
#              ('original_ngtdm_Strength', array(0.01097781))])

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Q5.</b> Analyse the extracted features. Identify potential attributes that could be useful to classify the tumor grade.
# </div>

# %%
... # example: tumor voxel volume, uniformity, etc.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Q6.</b> Implement and run the feature extraction without normalization and compare the results.
# </div>

# %%
...

# %% [markdown]
# Now that we better understand how to extract radiomic features from DICOM files associated with tumor masks, we will apply this to the whole dataset and transform the results to a csv file.

# %%
feature_list = []
# Loop over patients 
for patient, tumor in zip(clinical_df['Case Number'], clinical_df['WHO Grade']):
    # Use pre-defined function to load dicom series to 3D images, load mask and resample the mask to the image space
    idx = str(patient).zfill(3)
    img_dirname = glob(f'{DATA_PATH}/ReMIND/ReMIND-{idx}/*-Preop-*/*-3D*T1*-*')
    seg_fname = glob(
        f'{DATA_PATH}/PKG - ReMIND_NRRD_Seg_Sep_2023/ReMIND-{idx}/ReMIND-{idx}-preop-SEG-tumor-*.nrrd')

    if len(img_dirname) == 0 or len(seg_fname)==0:
        continue
        
    image_sitk = load_dicom_series_to_3d_image(img_dirname[0])
    mask, header = nrrd.read(seg_fname[0])
    mask_sitk = convert_np_to_sitk(mask, header)
    mask_resampled_sitk = resample_mask_to_image(mask_sitk, image_sitk)

    result = extractor.execute(image_sitk, mask_resampled_sitk)

    result['patient'] = patient
    result['tumor'] = tumor
    
    feature_list.append(result)
# Out:
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (216, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (216, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (512, 512, 168)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (256, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (512, 512, 201)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (512, 512, 364)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (208, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (512, 512, 172)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (224, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# [INFO] Loaded DICOM series with size: (256, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (256, 240, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# [INFO] Loaded DICOM series with size: (216, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (216, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (224, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (216, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (208, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (224, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (208, 256, 208)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (248, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (240, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# [INFO] Loaded DICOM series with size: (512, 512, 348)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (216, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (256, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (216, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (256, 256, 202)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# [INFO] Loaded DICOM series with size: (200, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (256, 256, 188)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (216, 256, 208)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# [INFO] Loaded DICOM series with size: (216, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (216, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (256, 256, 176)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (200, 256, 192)
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/egermani/miniforge3/envs/aim-course/include/ITK-5.4/itkImageSeriesReader.hxx, line
# [INFO] Loaded DICOM series with size: (256, 256, 192)

# %%
# gather all radiomics data into a df
radiomics = pd.DataFrame()

for feature in feature_list:
  new_df = pd.DataFrame.from_dict(data=feature, orient='index')
  radiomics = pd.concat([radiomics, new_df.iloc[22:].T]) # Remove 22 first features which won't be useful (metadata)

radiomics.to_csv('./radiomics.csv')

# %%
radiomics.head()
# Out:
#   original_shape_Elongation original_shape_Flatness  \
# 0                  0.838384                 0.72646
# 0                  0.845232                0.620404
# 0                  0.667052                0.532734
# 0                    0.9086                0.766401
#
#   original_shape_LeastAxisLength original_shape_MajorAxisLength  \
# 0                      29.469635                      40.566106
# 0                      25.020544                      40.329416
# 0                       18.33642                       34.41949
# 0                      12.618254                      16.464295
#
#   original_shape_Maximum2DDiameterColumn original_shape_Maximum2DDiameterRow  \
# 0                      48.27614183313007                  46.249061578894334
# 0                     39.962010706174674                   47.04535736780094
# 0                      32.60790435390819                   35.34176798469615
# 0                     18.868007991615258                    17.8045884683013
#
#   original_shape_Maximum2DDiameterSlice original_shape_Maximum3DDiameter  \
# 0                    45.091395787869615                48.35509553499142
# 0                     47.37083159386023                48.00932327638777
# 0                      31.5770830334028                40.00219792159095
# 0                     18.78829465868365               20.322452800090424
#
#   original_shape_MeshVolume original_shape_MinorAxisLength  ...  \
# 0         27223.61070815119                      34.009954  ...
# 0        23635.794206284252                      34.087712  ...
# 0         9781.914992357983                      22.959577  ...
# 0         2128.851694223878                      14.959458  ...
#
#   original_glszm_ZoneEntropy original_glszm_ZonePercentage  \
# 0          2.603596627078547         0.0009795347210075215
# 0          2.490819395967528          0.001690344910854429
# 0          2.321928094887361        0.00011215791834903544
# 0         0.9999999999999993         0.0009315323707498836
#
#   original_glszm_ZoneVariance original_ngtdm_Busyness  \
# 0           27915890.45280612      22.806783736156493
# 0           7225238.717120181       1213.294655157059
# 0                 290309643.6       56.90341414474545
# 0                  1111970.25       2.179260843864196
#
#   original_ngtdm_Coarseness original_ngtdm_Complexity original_ngtdm_Contrast  \
# 0      0.011025291665627891      0.006346024024414498  2.4431831398950516e-05
# 0     0.0005196120350000694       0.15490906557347373    0.037190897904257586
# 0        0.0045925971717719      0.009768583148411692   0.0002757361473068005
# 0       0.11626108430888703      0.008012417708705965     8.6288626406155e-05
#
#   original_ngtdm_Strength patient tumor
# 0    0.010977812308198063       1     3
# 0   0.0005204193039892505       2     2
# 0    0.004568426429063742       3     2
# 0     0.09469030844866835       4     1
#
# [4 rows x 109 columns]

# %% [markdown]
# ## Preprocess and clean

# %% [markdown]
# Now that we have extracted the radiomic features for all patients, we will process and clean the values.

# %% [markdown]
# ### Detect outliers
#
# To identify outliers, several strategies are possible.
#
# #### Median Absolute Deviation
# One of the most common is to use the MAD (Median Absolute Deviation) rule.
# This statistical outlier detection method uses the median and the median absolute deviation as robust estimators to identify outliers in a dataset.

# %%
# Define the threshold multiplier and the radiomic value to inspect
threshold=5.0
outlier_col = 'original_shape_VoxelVolume'
  
# Calculate the median
median = np.median(radiomics[outlier_col])
    
# Calculate the absolute differences from the median
abs_diff = np.abs(radiomics[outlier_col] - median)

# Calculate the MAD (Median Absolute Deviation)
mad = np.median(abs_diff)

# Define the threshold for outliers
outlier_threshold = threshold * mad

# Identify outliers based on the threshold
outliers = [i for i, x in enumerate(radiomics[outlier_col]) if np.abs(x - median) > outlier_threshold]

# %%
radiomics.iloc[outliers]
# Out:
#   original_shape_Elongation original_shape_Flatness  \
# 0                  0.615411                0.494542
#
#   original_shape_LeastAxisLength original_shape_MajorAxisLength  \
# 0                      44.923623                      90.838858
#
#   original_shape_Maximum2DDiameterColumn original_shape_Maximum2DDiameterRow  \
# 0                      75.73832979806562                   92.26874078812111
#
#   original_shape_Maximum2DDiameterSlice original_shape_Maximum3DDiameter  \
# 0                    100.17650370664803               102.99864699904953
#
#   original_shape_MeshVolume original_shape_MinorAxisLength  ...  \
# 0        125905.52612073209                      55.903192  ...
#
#   original_glszm_ZoneEntropy original_glszm_ZonePercentage  \
# 0           8.52445958598454            0.1960038706360846
#
#   original_glszm_ZoneVariance original_ngtdm_Busyness  \
# 0           276312.1551113672       7.030017261735116
#
#   original_ngtdm_Coarseness original_ngtdm_Complexity original_ngtdm_Contrast  \
# 0    2.7839478188053742e-05        126941.37152699278       0.235243697059528
#
#   original_ngtdm_Strength patient tumor
# 0      14.746387200021987      58     2
#
# [1 rows x 109 columns]

# %% [markdown]
# #### Interquartile Range
#
# The 1.5 IQR (Interquartile Range) rule uses the IQR to identify outliers based on quartiles.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Q7.</b> Complete the following code to check the results of this method compared to the MAD rule.
# </div>

# %%
# Define the radiomic value to inspect
outlier_col = 'original_shape_VoxelVolume'
  
# Calculate the median
q1 = np.q1(...) # COMPLETE
q3 = np.q3(...) # COMPLETE
    
# Calculate the interquartile range 
iqr = ... # COMPLETE

# Compute the lower and upper bounds
lower_bound = ... - 1.5 * ...
upper_bound = ... + 1.5 * ... 

# Identify outliers based on the threshold
outliers = [i for i, x in enumerate(radiomics[outlier_col]) if x > upper_bound or x < lower_bound]

# %%
radiomics.iloc[outliers]

# %% [markdown]
# #### More advanced strategies
#
# To detect outliers, we can use functions defined in `scikit-learn`.
#
# The **Local Outlier Factor** measures the local deviation of the density of a given sample with respect to its neighbors. By comparing the local density of a sample to the local densities of its neighbors, one can identify samples that have a substantially lower density than their neighbors. These are considered outliers.

# %%
from sklearn.neighbors import LocalOutlierFactor

clf = LocalOutlierFactor(n_neighbors=20, contamination=0.1)
y_pred = clf.fit_predict(radiomics.drop(['tumor'], axis=1))
n_errors = (y_pred != radiomics['tumor']).sum()
X_scores = clf.negative_outlier_factor_

# %%
X_scores
# Out:
# array([  -1.11041076,   -1.04057972,   -4.29156683,   -1.0065458 ,
#         -10.70529574,   -9.74721323,   -1.12062083,   -4.79101098,
#          -1.06378995,   -1.02111528,   -8.91584162,   -1.09355597,
#          -1.00720163,   -1.00262223,   -1.00262223,   -0.9673217 ,
#          -1.1386893 ,   -1.03963972,   -1.01588766,   -4.13495687,
#         -16.15981489,   -2.07639948,   -1.02041264,   -1.10966526,
#         -28.63086235,   -1.14139966,  -14.68855286,   -3.02179462,
#          -1.15215936,   -1.01633731,  -12.31764544,   -1.00602332,
#          -1.00966467,   -1.02728119,   -1.14384232,   -1.02441947,
#          -1.37762923,   -0.9579749 ,   -1.1117091 ,   -1.00896069,
#          -2.2289164 ,   -1.12767223,   -3.37943384,   -1.00262223,
#          -3.8720302 ,   -1.40948419,  -19.38580183,   -1.19428113,
#          -1.02198173,   -0.97926573,   -1.04036954,   -1.02318399,
#          -1.31994545,   -1.02770049,   -0.94680761,   -1.5315984 ,
#          -1.43834374,   -1.67113391,   -1.15710289,   -1.07015488,
#          -1.1124978 ,   -0.94219014,   -1.011404  ,   -1.32051149,
#          -1.14354854,   -1.02195676,   -1.1477281 ,   -1.03555241,
#          -1.018818  ,   -1.01339956, -168.60955618,   -1.00593177,
#          -1.09696704,   -1.00262223,   -1.43760278,   -1.35022035,
#          -1.19696583,   -0.95721512,   -0.97264389,   -1.74653507,
#          -1.16733455,   -1.06582807,   -1.11858216,   -1.16461259,
#          -0.94577446,   -1.16192664,   -1.0210006 ,   -1.02319006,
#          -1.44445589,  -34.02317925,   -1.1077274 ])

# %% [markdown]
# We can see samples with relatively low outlier scores. In practice, we could decide to remove these outliers, as too many outliers could prevent to learn proper boundary decisions for classification.

# %% [markdown]
# ### Standardization
#
# Different variables/features in a dataset have different range of value. To harmonize this, we usually use the **Z score**.
# By computing the Z scores of features, we can tell how many standard deviations away a data point is from the mean.
#
# Z scoring can also be used for outlier detection. After Z scoring, features follow a Normal distribution with:
# * 68% of the data points lie between +/- 1 standard deviation
# * 95% of the data points lie between +/- 2 standard deviation
# * 99.7% of the data points lie between +/- 3 standard deviation

# %% [markdown]
# Z scoring can be applied directly on features using predefined functions from `scikit-learn`.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler() # Create the scaler 
radiomics_zscore = scaler.fit_transform(radiomics.drop(['patient', 'tumor'], axis=1))
radiomics_zscore_df = pd.DataFrame(radiomics_zscore, columns=radiomics.columns[:-2])

radiomics_zscore_df
# Out:
#     original_shape_Elongation  original_shape_Flatness  \
# 0                    0.859229                 1.067034
# 1                    0.895260                 0.592973
# 2                   -0.042169                 0.201090
# 3                    1.228647                 1.245570
# 4                   -0.152393                -0.572770
# ..                        ...                      ...
# 86                   0.457693                 0.638465
# 87                   0.374252                 0.846058
# 88                   0.794730                 0.628109
# 89                  -0.587890                -0.024503
# 90                   0.643216                 0.284135
#
#     original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                         0.797794                       -0.403429
# 1                         0.384173                       -0.410317
# 2                        -0.237234                       -0.582293
# 3                        -0.768837                       -1.104782
# 4                        -0.142303                       -0.017470
# ..                             ...                             ...
# 86                        0.756396                       -0.244493
# 87                        0.676838                       -0.373154
# 88                        1.028097                       -0.104190
# 89                        1.399382                        0.584750
# 90                        0.974186                        0.071740
#
#     original_shape_Maximum2DDiameterColumn  \
# 0                                -0.065381
# 1                                -0.353053
# 2                                -0.607507
# 3                                -1.082911
# 4                                 0.024997
# ..                                     ...
# 86                               -0.143880
# 87                               -0.090410
# 88                                0.085712
# 89                                0.050946
# 90                                0.204546
#
#     original_shape_Maximum2DDiameterRow  \
# 0                             -0.272373
# 1                             -0.246853
# 2                             -0.621925
# 3                             -1.183949
# 4                              0.207070
# ..                                  ...
# 86                            -0.261433
# 87                            -0.457061
# 88                             0.046481
# 89                             0.708851
# 90                             0.631499
#
#     original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                               -0.090654                         -0.412250
# 1                                0.025922                         -0.421685
# 2                               -0.781809                         -0.640177
# 3                               -1.435860                         -1.177182
# 4                                0.552334                         -0.032896
# ..                                    ...                               ...
# 86                               0.373680                         -0.106827
# 87                               0.001084                         -0.402047
# 88                               0.651471                         -0.103774
# 89                               1.533752                          0.409321
# 90                               1.138724                          0.322204
#
#     original_shape_MeshVolume  original_shape_MinorAxisLength  ...  \
# 0                    0.118658                        0.172015  ...
# 1                   -0.035678                        0.178418  ...
# 2                   -0.631624                       -0.737961  ...
# 3                   -0.960833                       -1.396755  ...
# 4                   -0.176784                        0.235367  ...
# ..                        ...                             ...  ...
# 86                   0.232487                        0.259812  ...
# 87                  -0.026373                       -0.071990  ...
# 88                   0.781220                        0.830629  ...
# 89                   1.979846                        0.828458  ...
# 90                   1.181223                        1.106993  ...
#
#     original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       -0.256520
# 1                                       -0.283064
# 2                                       -0.111014
# 3                                       -0.257207
# 4                                        0.007254
# ..                                            ...
# 86                                      -0.258488
# 87                                      -0.192559
# 88                                      -0.236624
# 89                                       0.696503
# 90                                      -0.274323
#
#     original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                      -0.204795                   -0.462470
# 1                                       0.430202                   -0.220422
# 2                                      -0.427077                    0.776127
# 3                                      -0.291498                   -0.658263
# 4                                      -0.552812                    1.274900
# ..                                           ...                         ...
# 86                                     -0.207564                   -0.378335
# 87                                     -0.048562                    0.127941
# 88                                     -0.371944                    0.407363
# 89                                     -0.558208                    1.456018
# 90                                      0.158459                   -0.213057
#
#     original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       -0.822257                    -0.095128
# 1                       -0.790855                    -0.114257
# 2                       -0.417649                    -0.128351
# 3                       -0.164278                    -0.133651
# 4                        0.388209                    -0.134025
# ..                            ...                          ...
# 86                      -0.810364                    -0.099097
# 87                      -0.298503                    -0.093389
# 88                       0.226401                    -0.133179
# 89                       2.281285                    -0.134130
# 90                      -0.704508                    -0.096403
#
#     original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                 -0.081902                  -0.195262
# 1                 -0.040694                  -0.184531
# 2                 -0.271384                  -0.197609
# 3                 -0.305896                  -0.025903
# 4                 -0.296132                  -0.202788
# ..                      ...                        ...
# 86                -0.149964                  -0.194169
# 87                -0.142315                  -0.178807
# 88                -0.023377                  -0.197567
# 89                -0.269356                  -0.207990
# 90                 0.095901                  -0.201689
#
#     original_ngtdm_Complexity  original_ngtdm_Contrast  \
# 0                   -0.148660                -0.713150
# 1                   -0.151587                -0.651935
# 2                   -0.141318                -0.536644
# 3                   -0.151176                -0.452287
# 4                   -0.007830                -0.558924
# ..                        ...                      ...
# 86                  -0.150348                -0.708106
# 87                  -0.145205                 0.153554
# 88                  -0.146786                 0.055132
# 89                   0.545303                 1.165971
# 90                  -0.151516                -0.595890
#
#     original_ngtdm_Strength
# 0                 -0.208590
# 1                 -0.347854
# 2                 -0.324345
# 3                 -0.199718
# 4                  0.239030
# ..                      ...
# 86                -0.313895
# 87                -0.074994
# 88                -0.395266
# 89                -0.154153
# 90                -0.404523
#
# [91 rows x 107 columns]

# %% [markdown]
# Now that we have z-scored data, we can use the thresholds explained above to detect outliers.

# %%
# Extreme values based on outlier columns.
radiomics_zscore_df[(radiomics_zscore_df[outlier_col]<-3) | (radiomics_zscore_df[outlier_col]>3)]
# Out:
#     original_shape_Elongation  original_shape_Flatness  \
# 46                  -0.313859                 0.030375
#
#     original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 46                        2.234512                        1.059488
#
#     original_shape_Maximum2DDiameterColumn  \
# 46                                0.884818
#
#     original_shape_Maximum2DDiameterRow  \
# 46                             1.202447
#
#     original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 46                               2.726535                           1.07882
#
#     original_shape_MeshVolume  original_shape_MinorAxisLength  ...  \
# 46                   4.363617                        1.974879  ...
#
#     original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 46                                       1.699771
#
#     original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 46                                     -0.399868                    1.760514
#
#     original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 46                      -0.042076                     0.026415
#
#     original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 46                 0.079539                  -0.210306
#
#     original_ngtdm_Complexity  original_ngtdm_Contrast  \
# 46                   0.362065                 0.853583
#
#     original_ngtdm_Strength
# 46                 1.392987
#
# [1 rows x 107 columns]

# %%
# Save our standardized measures 
radiomics_zscore_df['patient'] = radiomics['patient'].values
radiomics_zscore_df['tumor'] = radiomics['tumor'].values
radiomics_zscore_df.to_csv('./radiomics_standardized.csv', index=False)
